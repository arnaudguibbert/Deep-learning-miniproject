# %% [markdown]
# # Import

# %%
import torch
import torch.nn as nn
from metrics import Cross_validation
from architecture import *
from dlc_practical_prologue import generate_pair_sets as load_data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Define the architectures and parameters

# %%
# List of the architectures you want to assess
architectures = [Naive_net,CrossArchitecture]
# List of the arguments for each architecture
args = [[],[]]
# Initialize the cross validation
mytest = Cross_validation(architectures,args,epochs=25,steps=5,runs=5)

# %% [markdown]
# # Run the network

# %%
mytest.reset()
mytest.run_all("CrossArchitecture")
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# 60
# 65
# 70
# CrossArchitecture   0              99.2                     90.3
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# 60
# 65
# 70
# CrossArchitecture   1              98.8                     89.1
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-e99e313ae329> in <module>
#       1 mytest.reset()
# ----> 2 mytest.run_one("CrossArchitecture")
#
# ~\Programming\Python\Deep_learning\Deep-learning-miniproject\Proj1\metrics.py in run_one(self, archi_name)
#     136                                 train_target,
#     137                                 train_classes,
# --> 138                                 nb_epochs=self.steps)
#     139                     accuracy_train = self.accuracy(model,train_input,train_target)
#     140                     accuracy_test = self.accuracy(model,test_input,test_target)
#
# ~\Programming\Python\Deep_learning\Deep-learning-miniproject\Proj1\metrics.py in train_model(model, train_input, train_target, train_classes, nb_epochs, mini_batch_size, eta, criterion)
#      33                 loss = criterion(output, train_target.narrow(0, b, mini_batch_size))
#      34             model.zero_grad()
# ---> 35             loss.backward()
#      36             optimizer.step()
#      37
#
# ~\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize the accuracy evolution

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_evolution("CrossArchitecture",fig,[1,1,1])

# %% [markdown]
# # Visualize the spread of the accuracy

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_std(fig,[1,1,1])

# %% [markdown]
# # Compare the performances

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_evolution_all(fig,[1,1,1],test=False)

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_evolution_all(fig,[1,1,1])

# %% [markdown]
# # Let's plot all these graphs together

# %%
mytest.plot_full_comparison()

# %%
a = torch.empty(4,2,14,14).normal_(3)
a.requires_grad = True
b0 = a[:,[0],:,:]
b1 = a[:,[1],:,:]
print(b.requires_grad)
# Out:
# True

# %%
b.shape
# Out:
# torch.Size([4, 1, 14, 14])

# %%
c1 = torch.empty(4,10).normal_(3).view(4,-1,1)
c2 = torch.empty(4,10).normal_(3).view(4,-1,1)

# %%
torch.cat((c1,c2),dim=2).shape
# Out:
# torch.Size([4, 10, 2])

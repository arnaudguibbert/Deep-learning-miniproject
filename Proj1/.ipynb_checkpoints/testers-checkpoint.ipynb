# %% [markdown]
# # Import

# %%
import torch
from metrics import Cross_validation
from architecture import *
from dlc_practical_prologue import generate_pair_sets as load_data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Define the architectures and parameters

# %%
# List of the architectures you want to assess
architectures = [Naive_net,Naive_net]
# List of the arguments for each architecture
args = [[],[]]
# Initialize the cross validation
mytest = Cross_validation(architectures,args,epochs=100,steps=10,runs=5)

# %% [markdown]
# # Run the network

# %%
mytest.run_one("Naive_net")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-62ac36c49a3e> in <module>
# ----> 1 mytest.run_one("Naive_net")
#
# ~\Programming\Python\Deep_learning\Deep-learning-miniproject\Proj1\metrics.py in run_one(self, archi_name)
#     145                                 nb_epochs=self.steps)
#     146                     accuracy_train = self.accuracy(model,train_input,train_target)
# --> 147                     accuracy_test = self.accuracy(model,test_input,test_target)
#     148                     row_test = torch.tensor([runs,index,accuracy_test,1,step]).view(1,-1)
#     149                     row_train = torch.tensor([runs,index,accuracy_train,0,step]).view(1,-1)
#
# ~\Programming\Python\Deep_learning\Deep-learning-miniproject\Proj1\metrics.py in accuracy(self, model, input, target)
#     114         Outputs:
#     115         """
# --> 116         output = model(input)
#     117         _,predicted = torch.max(output,dim=1)
#     118         errors = torch.where(target != predicted,1,0).sum().item()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Programming\Python\Deep_learning\Deep-learning-miniproject\Proj1\architecture.py in forward(self, input)
#      22
#      23     def forward(self,input):
# ---> 24         output = self.sequence(input)
#      25         return output
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     153         return F.max_pool2d(input, self.kernel_size, self.stride,
#     154                             self.padding, self.dilation, self.ceil_mode,
# --> 155                             self.return_indices)
#     156
#     157
#
# ~\Anaconda3\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     265             return if_true(*args, **kwargs)
#     266         else:
# --> 267             return if_false(*args, **kwargs)
#     268
#     269     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     584         stride = torch.jit.annotate(List[int], [])
#     585     return torch.max_pool2d(
# --> 586         input, kernel_size, stride, padding, dilation, ceil_mode)
#     587
#     588 max_pool2d = boolean_dispatch(
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize the accuracy evolution

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_evolution("Naive_net",fig,111)

# %% [markdown]
# # Visualize the spread of the accuracy

# %%
fig = plt.figure(figsize=[8,4])
sns.set_style("darkgrid")
mytest.plot_std(fig,111)
